# %%
# !pip show torch
# !pip install geomloss
# Out:
# Name: torch
# Version: 2.1.2+cu121
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: d:\programdata\anaconda3\envs\pth\lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, typing-extensions
# Required-by:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for geomloss: filename=geomloss-0.2.6-py3-none-any.whl size=32260 sha256=37f95ee52e6564c90c712dbd94022dbcbd7402040da2990bf9b8376d5ac1c543
#   Stored in directory: c:\users\mathp\appdata\local\pip\cache\wheels\0d\c9\80\4387eb03aa215ae557869d6fe8be498fd3d3cf297db2357b67
# Successfully built geomloss
# ...

# %%
# !nvidia-smi
# Out:
# Sat Jan 13 19:49:57 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.33                 Driver Version: 546.33       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1050      WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   40C    P8              N/A / ERR! |     98MiB /  4096MiB |     30%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# pip install torch-scatter -f https://data.pyg.org/whl/torch-2.1.0+cu121.html
# pip install torch-sparse -f https://data.pyg.org/whl/torch-2.1.0+cu121.html

# %%
# %%time
# %run teacher_mvc.py

# CPU times: total: 22.5 s
# Wall time: 24.4 s
# Out:
# Loading config...
# Loading dataset...
# Initializing weights...
# Get teacher model
# In channels: 1024
# Hidden channels: 128
# Out channels: 2
# Reseting model parameters...
# Get optimizer
# Learning rate: 0.001
# Weight decay: 0.0005
# Start training...
# Acc_best is updated to 0.5376. Model checkpoint is saved to ./model/Cora_MVC_Teacher.pt.
# Test accuracy is 0.5358
# Acc_best is updated to 0.5831. Model checkpoint is saved to ./model/Cora_MVC_Teacher.pt.
# Test accuracy is 0.5827
# Acc_best is updated to 0.7045. Model checkpoint is saved to ./model/Cora_MVC_Teacher.pt.
# Test accuracy is 0.7016
# Acc_best is updated to 0.7421. Model checkpoint is saved to ./model/Cora_MVC_Teacher.pt.
# Test accuracy is 0.7415
# Acc_best is updated to 0.7919. Model checkpoint is saved to ./model/Cora_MVC_Teacher.pt.
# Test accuracy is 0.7903
# Acc_best is updated to 0.7926. Model checkpoint is saved to ./model/Cora_MVC_Teacher.pt.
# Test accuracy is 0.7939
# ...

# %%
# %%time
# %run student_mvc.py
# Out:
# Loading config...
# Loading dataset...
# Loading teacher model...
# Teacher GNN backbone is GraphSAGE
# In channels: 1024
# Hidden channels: 128
# Out channels: 2
# Loading weights...
# Get student model
# Student GNN backbone is GraphSAGE
# In channels: 1024
# Hidden channels: 32
# Out channels: 2
# Reseting model parameters...
# Get optimizer
# Learning rate: 0.0001
# Weight decay: 0.0005
# Start training...
# Test accuracy is 0.5284
# Test accuracy is 0.5883
# Test accuracy is 0.6621
# Test accuracy is 0.7182
# Test accuracy is 0.7434
# Test accuracy is 0.7581
# Test accuracy is 0.7710
# Test accuracy is 0.7762
# Test accuracy is 0.7843
# Test accuracy is 0.7884
# Test accuracy is 0.7939
# Epoch: [100/1000] loss_train: 0.2271 acc_train: 0.7440 acc_val: 0.7630
# Test accuracy is 0.8010
# Test accuracy is 0.8024
# Test accuracy is 0.8058
# Test accuracy is 0.8091
# Test accuracy is 0.8150
# Test accuracy is 0.8157
# Test accuracy is 0.8172
# Test accuracy is 0.8179
# ...

# %%
Epoch: [1000/1000] loss_train: 0.1550 acc_train: 0.8731 acc_val: 0.8837
Final accuracy is 0.8903

Epoch: [1000/1000] loss_train: 0.1550 acc_train: 0.8731 acc_val: 0.8837
Final accuracy is 0.8900

Epoch: [1000/1000] loss_train: 0.1551 acc_train: 0.8731 acc_val: 0.8844
Test accuracy is 0.8903
Final accuracy is 0.8903

# %% [markdown]
# Wass Student 0.1
# Epoch: [1000/1000] loss_train: 0.3321 acc_train: 0.8678 acc_val: 0.8757
# Final accuracy is 0.8800
#
# Wass Student 0.01
# Epoch: [1000/1000] loss_train: 0.1720 acc_train: 0.8716 acc_val: 0.8808
# Final accuracy is 0.8855
#
# Wass Student 0.001
# Epoch: [1000/1000] loss_train: 0.1558 acc_train: 0.8708 acc_val: 0.8837
# Final accuracy is 0.8900

# %%
# %%time
# %run eval_mvc.py
# Out:
# Loading dataset...
# recall: 0.9322
# acc_test: 0.9541
# recall: 0.8912
# acc_test: 0.9536
# CPU times: total: 1.61 s
# Wall time: 1.04 s

# %%
# %%time
# %run combhelper.py MVC GD OTC
# Out:
# Problem: MVC
# GD:
# Time elapsed: 18.696s
# Solution size: 1553
# GD+COMBHelper_{pt}:
# Time elapsed: 2.686s
# Solution size: 1519
# Coverage: 0.9984
# GD+COMBHelper:
# Time elapsed: 3.024s
# Solution size: 1551
# Coverage: 1.0000
# CPU times: total: 25 s
# Wall time: 25.1 s

# %% [markdown]
# Finally it worked :)
